# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanth5reddy/D2L/blob/master/Multilayer%20Perceptrons/multilayer_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/My Drive/Colab/D2L.AI/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Installing Libraries

# %%
# !pip install mxnet

# %% [markdown]
# Importing Libraries

# %%
# %matplotlib inline
import d2l
from mxnet import autograd, nd

# %% [markdown]
# ReLU Function
#
# **ReLU(x) = max(x,0)**

# %%
def xyplot(x_vals, y_vals, name):
  d2l.set_figsize(figsize=(5, 2.5))
  d2l.plt.plot(x_vals.asnumpy(), y_vals.asnumpy())
  d2l.plt.xlabel('x')
  d2l.plt.ylabel(name + '(x)')

# %%
x = nd.arange(-8.0, 8.0, 0.1)
x.attach_grad()
with autograd.record():
  y = x.relu()
xyplot(x, y, 'relu')

# %%
y.backward()
xyplot(x, x.grad, 'grad of relu')

# %% [markdown]
# Sigmoid Function
#
# **sigmoid(x) = 1 / (1+exp(−x))**

# %%
with autograd.record():
    y = x.sigmoid()
xyplot(x, y, 'sigmoid')

# %%
y.backward()
xyplot(x, x.grad, 'grad of sigmoid')

# %% [markdown]
# Tanh Function
#
# **tanh(x) = (1−exp(−2x)) / (1+exp(−2x))**

# %%
with autograd.record():
    y = x.tanh()
xyplot(x, y, 'tanh')

# %%
y.backward()
xyplot(x, x.grad, 'grad of tanh')

# %% [markdown]
# **Summary :** ReLU is better than Sigmoid and Tanh
