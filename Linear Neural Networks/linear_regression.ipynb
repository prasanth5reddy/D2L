# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanth5reddy/D2L/blob/master/Linear%20Neural%20Networks/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing Libraries

# %%
# !pip install mxnet

# %% [markdown]
# Importing Libraries

# %%
from mxnet import nd
from time import time
import numpy as np
import math
from matplotlib import pyplot as plt
from IPython import display
# %matplotlib inline

# %% [markdown]
# Vectorization For Speed

# %%
a = nd.ones(shape=10000)
b = nd.ones(shape=10000)

# %%
start = time()
c = nd.zeros(shape=10000)
for i in range(10000):
    c[i] = a[i] + b[i]
time() - start
# Out:
# 2.331367015838623

# %%
start = time()
d = a + b
time() - start
# Out:
# 0.0009920597076416016

# %% [markdown]
# The Normal Distribution and Squared Loss

# %%
x = nd.arange(-7, 7, 0.01)
# Mean and variance pairs
parameters = [(0,1), (0,2), (3,1)]

# Display SVG rather than JPG
display.set_matplotlib_formats('svg')
plt.figure(figsize=(10, 6))
for (mu, sigma) in parameters:
    p = (1/math.sqrt(2 * math.pi * sigma**2)) * nd.exp(-(0.5/sigma**2) * (x-mu)**2)
    plt.plot(x.asnumpy(), p.asnumpy(), label='mean ' + str(mu) + ', variance ' + str(sigma))

plt.legend()
plt.show()

# %%
# maximum likelihood in a linear model with additive Gaussian noise is equivalent to linear regression with squared loss

# %% [markdown]
# Exercises

# %%
# 4
e = np.ones(1000)
f = np.ones(1000)

# %%
start = time()
g = e + f
time() - start
# Out:
# 0.00012087821960449219
